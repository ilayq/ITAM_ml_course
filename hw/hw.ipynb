# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('adult_data.csv')
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df[df['sex'] == 'Male']
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 32553   32           Private  116138       Masters             14
# 32554   53           Private  321865       Masters             14
# 32555   22           Private  310152  Some-college             10
# 32557   40           Private  154374       HS-grad              9
# 32559   22           Private  201490       HS-grad              9
#
#            marital-status         occupation   relationship  \
# 0           Never-married       Adm-clerical  Not-in-family
# ...

# %%
df[df['sex'] == "Female"]
# Out:
#        age     workclass  fnlwgt     education  education-num  \
# 4       28       Private  338409     Bachelors             13
# 5       37       Private  284582       Masters             14
# 6       49       Private  160187           9th              5
# 8       31       Private   45781       Masters             14
# 12      23       Private  122272     Bachelors             13
# ...    ...           ...     ...           ...            ...
# 32546   37       Private  198216    Assoc-acdm             12
# 32549   43     State-gov  255835  Some-college             10
# 32556   27       Private  257302    Assoc-acdm             12
# 32558   58       Private  151910       HS-grad              9
# 32560   52  Self-emp-inc  287927       HS-grad              9
#
#               marital-status       occupation    relationship   race     sex  \
# 4         Married-civ-spouse   Prof-specialty            Wife  Black  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df[df.sex == 'Male'].describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  21790.000000  2.179000e+04   21790.000000  21790.000000  21790.000000
# mean      39.433547  1.917714e+05      10.102891   1329.370078    100.213309
# std       13.370630  1.067407e+05       2.662630   8326.312095    429.763097
# min       17.000000  1.376900e+04       1.000000      0.000000      0.000000
# 25%       29.000000  1.182008e+05       9.000000      0.000000      0.000000
# 50%       38.000000  1.801400e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.411462e+05      13.000000      0.000000      0.000000
# max       90.000000  1.455435e+06      16.000000  99999.000000   3770.000000
#
#        hours-per-week
# count    21790.000000
# mean        42.428086
# std         12.119755
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         49.000000
# max         99.000000

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df[df['native-country'] == 'Taiwan'].count()
# Out:
# age               51
# workclass         51
# fnlwgt            51
# education         51
# education-num     51
# marital-status    51
# occupation        51
# relationship      51
# race              51
# sex               51
# capital-gain      51
# capital-loss      51
# hours-per-week    51
# native-country    51
# salary            51
# dtype: int64

# %%
51 / 32561
# Out:
# 0.001566290961579804

# %%
df[df.salary == '>50K'].describe()
# Out:
#                age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  7841.000000  7.841000e+03    7841.000000   7841.000000   7841.000000
# mean     44.249841  1.880050e+05      11.611657   4006.142456    195.001530
# std      10.519028  1.025418e+05       2.385129  14570.378951    595.487574
# min      19.000000  1.487800e+04       2.000000      0.000000      0.000000
# 25%      36.000000  1.191010e+05      10.000000      0.000000      0.000000
# 50%      44.000000  1.761010e+05      12.000000      0.000000      0.000000
# 75%      51.000000  2.309590e+05      13.000000      0.000000      0.000000
# max      90.000000  1.226583e+06      16.000000  99999.000000   3683.000000
#
#        hours-per-week
# count     7841.000000
# mean        45.473026
# std         11.012971
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         50.000000
# max         99.000000

# %%
df[df.salary == '>50K'].education
# Out:
# 7             HS-grad
# 8             Masters
# 9           Bachelors
# 10       Some-college
# 11          Bachelors
#              ...
# 32539       Doctorate
# 32545      Assoc-acdm
# 32554         Masters
# 32557         HS-grad
# 32560         HS-grad
# Name: education, Length: 7841, dtype: object

# %%
df[(df['native-country'] == 'United-States') & (df.salary == '<=50K') & (df['hours-per-week'] == 40)].count()
# Out:
# age               10493
# workclass         10493
# fnlwgt            10493
# education         10493
# education-num     10493
# marital-status    10493
# occupation        10493
# relationship      10493
# race              10493
# sex               10493
# capital-gain      10493
# capital-loss      10493
# hours-per-week    10493
# native-country    10493
# salary            10493
# dtype: int64

# %%
df['hours-per-week'].max()
# Out:
# 99

# %%
df[df['hours-per-week'] == 99]
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 935     37           Private  176900       HS-grad              9
# 1172    25           Private  404616       Masters             14
# 1887    55  Self-emp-not-inc  184425  Some-college             10
# 3578    37      Self-emp-inc  382802     Doctorate             16
# 4086    50                 ?  174964          10th              6
# ...    ...               ...     ...           ...            ...
# 30992   40      Self-emp-inc  104235       Masters             14
# 31681   43           Private  266324       HS-grad              9
# 31699   43  Self-emp-not-inc  163108  Some-college             10
# 32469   58      Self-emp-inc  181974     Doctorate             16
# 32531   30                 ?   33811     Bachelors             13
#
#            marital-status       occupation   relationship                race  \
# 935    Married-civ-spouse     Craft-repair        Husband               White
# ...

# %%
df[(df.salary == '<=50K') & (df['hours-per-week'] == 99)]
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 4086    50                 ?  174964          10th              6
# 4308    35  Self-emp-not-inc  166416       HS-grad              9
# 5376    43           Private   86750     Assoc-voc             11
# 5432    44           Private   83508   Prof-school             15
# 6618    27           Private  336951       HS-grad              9
# 6898    53  Self-emp-not-inc  151159          10th              6
# 8072    44  Self-emp-not-inc   26669    Assoc-acdm             12
# 8654    30           Private  103596       HS-grad              9
# 9811    28           Private   27956   Prof-school             15
# 9831    67           Private   35015       Masters             14
# 10143   35                 ?  164866          10th              6
# 10266   56      Self-emp-inc  184598           9th              5
# 10468   44  Self-emp-not-inc  277783       Masters             14
# ...

# %%
education_groups = df.groupby('education')
values = set(df.education.tolist())
r = {}
for value in values:
    r[value] = len(df[df.education == value])
r
# Out:
# {'Bachelors': 5355,
#  'HS-grad': 10501,
#  'Assoc-acdm': 1067,
#  'Assoc-voc': 1382,
#  '10th': 933,
#  '1st-4th': 168,
#  '11th': 1175,
#  'Preschool': 51,
#  '12th': 433,
#  '9th': 514,
#  'Doctorate': 413,
#  'Masters': 1723,
#  'Some-college': 7291,
#  '7th-8th': 646,
#  'Prof-school': 576,
#  '5th-6th': 333}

# %%
plt.bar(r.keys(), r.values())
plt.figure(figsize=(100, 10))

# %%
df.groupby('age').size()
# Out:
# age
# 17    395
# 18    550
# 19    712
# 20    753
# 21    720
#      ...
# 85      3
# 86      1
# 87      1
# 88      3
# 90     43
# Length: 73, dtype: int64
